# %%
# !pip install sentence_transformers
# !pip install faiss-gpu
# Out:
# Collecting sentence_transformers
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.44.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.4.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.24.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: sentence_transformers
# Successfully installed sentence_transformers-3.0.1
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 9.2 MB/s eta 0:00:00
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2

# %%
import torch
from sentence_transformers import SentenceTransformer, CrossEncoder
import faiss
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
sbert_model = SentenceTransformer('paraphrase-MiniLM-L6-v2', device=device)
cross_encoder = CrossEncoder('cross-encoder/stsb-roberta-base')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]

# %%
dog_data = pd.read_csv('cleaned_dataset.csv')

# %%
numeric_features = ['Average Cost', 'Average Height', 'Average Weight']
scaler = StandardScaler()
dog_data[numeric_features] = scaler.fit_transform(dog_data[numeric_features])

# %%
# Обработка shedding данных в зависимости от пользовательского ввода
def process_shedding(dog_data, shedding_input):
    dog_data['Sheds Little'] = 0
    dog_data['Sheds'] = 0
    dog_data['Sheds A Lot'] = 0

    if shedding_input == 'Sheds Little':
        dog_data['Sheds Little'] = 1
    elif shedding_input == 'Sheds':
        dog_data['Sheds'] = 1
    elif shedding_input == 'Sheds A Lot':
        dog_data['Sheds A Lot'] = 1
    elif shedding_input == 'No Sheds':
        dog_data['Sheds Little'] = 0
        dog_data['Sheds'] = 0
        dog_data['Sheds A Lot'] = 0

    return dog_data

# %%
def denormalize(value, column_name):
    mean = scaler.mean_[numeric_features.index(column_name)]
    std = scaler.scale_[numeric_features.index(column_name)]
    return value * std + mean

# %%
def denormalize_features(dog):
    original_cost = denormalize(dog['Average Cost'], 'Average Cost')
    original_height = denormalize(dog['Average Height'], 'Average Height')
    original_weight = denormalize(dog['Average Weight'], 'Average Weight')
    return original_cost, original_height, original_weight

# %%
def relevance_to_percentage(distances):
    relevance_scores = 1 / (distances + 1e-5)
    relevance_normalized = relevance_scores / np.max(relevance_scores)
    return relevance_normalized

# %%
def encode_text(text, model):
    if not isinstance(text, str):
        text = str(text)
    embeddings = model.encode(text, convert_to_tensor=True).cpu().numpy()
    return embeddings

# %%
dog_data['embedding'] = dog_data['Description'].apply(lambda x: encode_text(x, sbert_model))

# %%
def combine_features(text_embedding, numeric_data, sheds_data, care_experience):
    return np.hstack((text_embedding, numeric_data, sheds_data, [care_experience]))

# %%
dog_data['combined_embedding'] = dog_data.apply(
    lambda row: combine_features(
        row['embedding'],
        row[numeric_features].values,
        row[['Sheds Little', 'Sheds', 'Sheds A Lot']].values,
        row['Care Experience']
    ), axis=1
)

# %%
combined_embeddings = np.vstack(dog_data['combined_embedding'].values).astype('float32')
dimension = combined_embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(combined_embeddings)

# %%
def search_dogs(query, cost=None, sheds=None, height=None, weight=None, care_experience=None, n_results=5):
    # Кодирование пользовательского запроса (текст)
    query_embedding = encode_text(query, sbert_model)

    # Нормализация введённых пользователем числовых параметров
    query_numeric = np.array([cost, height, weight]).reshape(1, -1)
    query_numeric = scaler.transform(query_numeric)

    # Обработка shedding данных в соответствии с пользовательским вводом
    sheds_data = np.array([0, 0, 0]).reshape(1, -1) # Reshape to 2D
    if sheds == 'Sheds Little':
        sheds_data = np.array([1, 0, 0]).reshape(1, -1) # Reshape to 2D
    elif sheds == 'Sheds':
        sheds_data = np.array([0, 1, 0]).reshape(1, -1) # Reshape to 2D
    elif sheds == 'Sheds A Lot':
        sheds_data = np.array([0, 0, 1]).reshape(1, -1) # Reshape to 2D

    # Комбинирование эмбеддинга запроса и нормализованных данных
    combined_query_embedding = np.hstack((query_embedding.reshape(1, -1), query_numeric, sheds_data, np.array([care_experience]).reshape(1, -1))).astype('float32') # Reshape to 2D

    # Поиск ближайших соседей в FAISS
    distances, indices = index.search(combined_query_embedding, n_results)

    # Преобразование расстояний на основе обратного расстояния
    relevance_percentages = relevance_to_percentage(distances[0])

    # Формирование результатов поиска
    results = []
    for i, idx in enumerate(indices[0]):
        dog = dog_data.iloc[idx]
        results.append({
            "Name": dog['Name'],
            "Description": dog['Description'],
            "Original Cost": denormalize(dog['Average Cost'], 'Average Cost'),
            "Original Height": denormalize(dog['Average Height'], 'Average Height'),
            "Original Weight": denormalize(dog['Average Weight'], 'Average Weight'),
            "Care Experience Needed": dog['Care Experience'],
            "Relevance Score": relevance_percentages[i]
        })
    return results

# %%
def asymmetric_search(query, cost=None, sheds=None, height=None, weight=None, care_experience=None, n_results=3):
    # Подготовка пользовательских параметров
    query_numeric = np.array([cost, height, weight]).reshape(1, -1)
    query_numeric = scaler.transform(query_numeric)

    # Обработка shedding данных в соответствии с пользовательским вводом
    sheds_data = np.array([0, 0, 0])
    if sheds == 'Sheds Little':
        sheds_data = np.array([1, 0, 0])
    elif sheds == 'Sheds':
        sheds_data = np.array([0, 1, 0])
    elif sheds == 'Sheds A Lot':
        sheds_data = np.array([0, 0, 1])

    # Подготовка всех данных для CrossEncoder
    results = []
    for idx, row in dog_data.iterrows():
        # Создаём объединённую строку для CrossEncoder на основе описания и числовых данных
        description = row['Description']
        combined_text = f"{description}. Цена: {denormalize(row['Average Cost'], 'Average Cost'):.2f}, " \
                        f"Рост: {denormalize(row['Average Height'], 'Average Height'):.2f}, " \
                        f"Вес: {denormalize(row['Average Weight'], 'Average Weight'):.2f}, " \
                        f"Sheds: {row['Sheds Little']}/{row['Sheds']}/{row['Sheds A Lot']}, " \
                        f"Требуется опыт ухода: {'Да' if row['Care Experience'] == 1 else 'Нет'}."

        # Оценка CrossEncoder
        score = cross_encoder.predict([(query, combined_text)])[0]
        results.append((score, idx))

    # Сортировка по оценкам релевантности и выбор топ-N
    sorted_results = sorted(results, key=lambda x: x[0], reverse=True)[:n_results]

    # Формирование выходных данных
    output = []
    for score, idx in sorted_results:
        dog = dog_data.iloc[idx]
        output.append({
            "Name": dog['Name'],
            "Description": dog['Description'],
            "Original Cost": denormalize(dog['Average Cost'], 'Average Cost'),
            "Original Height": denormalize(dog['Average Height'], 'Average Height'),
            "Original Weight": denormalize(dog['Average Weight'], 'Average Weight'),
            "Care Experience Needed": dog['Care Experience'],
            "Relevance Score": score
        })

    return output

# %%
query = "маленькая дружелюбная собака для квартиры"
cost = 45  # Цена
height = 50  # Рост
weight = 20  # Вес
care_experience = 1  # Нужен опыт ухода за собакой
sheds = 'Sheds Little'  # Выбор по shedding

# %%
results = search_dogs(query, cost, sheds, height, weight, care_experience, 5)

# Вывод результатов
for result in results:
    print(f"Порода: {result['Name']}")
    print(f"Цена: {result['Original Cost']:.2f}")
    print(f"Рост: {result['Original Height']:.2f}")
    print(f"Вес: {result['Original Weight']:.2f}")
    print(f"Опыт ухода: {'Да' if result['Care Experience Needed'] == 1 else 'Нет'}")
    print(f"Релевантность: {result['Relevance Score']}")
    print(f"Описание: {result['Description']}\n")
# Out:
# Порода: Фараонова собака
# Цена: 67.50
# Рост: 47.60
# Вес: 22.50
# Опыт ухода: Да
# Релевантность: 1.0
# Описание: фараоновый собака ить фарао хаунд род мальты считаться национальный достояние страна называться кельб тальфенек перевод означать кроличий собака мальтийский кроличий борзая обладать великолепный спортивный охотничий качествами использоваться охота зайцев кролик другой некрупный дичь идеально подходить компаньон питомец семьи элегантный мальтийский собака преследовать дикий зверь позрячему свой телосложение напоминать пёс поденко ибиценко дело абсолютно разный породы иметь никакой родственный связей единственный связывает статус борзых мальтийский борзая  врождённый аристократ интеллектуалы энергичные умные игривый общительный питомцы отличаться спокойным уравновесить характером достаточно упрямые обладать хороший мышлением ласковы феноменально миролюбивый открытый домочадец друг семьи хозяин испытывать тёплый чувство сильный привязанность надоедливые важно ощущать полноправный член семьи удовольствие дружить гиперактивный детьми домашний животным мелким относиться враждебно поскольку анибусов ярко развитой охотничий инстинкт другой собака уживаются незнакомый человек проявлять лёгкий недоверие агрессии поэтому качество сторож подходят грозно облаять чужак крикливый ворон улице прекрасный спортсмены аджилити фризбить спортивный беге мягкий воспитательный метод легко поддаваться воспитание дрессировке недопустимо использовать принуждение физический наказание средний цена щенок фараоновый собака 4590 рублей активный фараоновый собака подходить загородный обширный территорией квартира уход мальтиец несложен кормление использоваться сушка класс суперпремиум холистик либо натурпродукты фараонов отменный здоровье генетический уровень предрасположенный отдельный патологиям средний продолжительность жизнь 1517 лет фарао хаунд подходить исключительно охотник активный людям смочь обеспечить питомец ежедневный активный прогулка питанием учитывать особенность организма
#
# Порода: Барбет
# Цена: 70.00
# Рост: 59.50
# Вес: 24.50
# Опыт ухода: Да
# Релевантность: 0.9158082604408264
# Описание: обладать плотный курчавый шерстью покрывать макушка широкий голова кончик изогнутый хвоста но несмотря забавный внешность сильная крепко сложить собака век разводиться увлечь охотника смышлёный быстро осваивать новый команда навыки предположительно название происходить французский barbe  борода действительно взрослый особь обладать настоящий густой бородкой главное достоинство  шерсть вызывающий аллергия равномерно покрывать тело вьющийся натуральный локонами волос макушка достигать переносицы чрезвычайно выносливы измотать взрослый особь понадобиться немало усилий благодаря плотный волосяной покров плавать холодный вода вред себя спокойный темперамент легко пор потребность упражнение физический нагрузка удовлетворяются верный друзья предать свой владельцу общительные игривые послушные энергичные компаньон ребёнок дошкольный возраста подвижный дружелюбны новый знакомство являться повод радости причина любить заводить семья детьми француз весьма умны нередкий препятствие процесс обучение служить своенравие свободолюбие нравиться выполнение команд непослушны показать недовольство поэтому опыт дрессировки следовать воспользоваться услуга кинолога покупать проверить продавца плюс щенок известный родословная хороший наследственность зависеть здоровье француз  редкий порода связь цена высока нуждаться активный прогулка 2 час день склонный полнота достаточный физический нагрузки вследствие важно следить меню любимца выбирать корм соответствие рекомендация ветеринарный врач заводчика шерсть цеплять листья ветка прочий мелкий мусор поэтому настоятельно рекомендоваться проводить ежедневный расчесывание поддерживать достойный состоянии необходимо частично обрезать лишний волосяной покров лёгкий чистить огромный плюс наличие поблизости дом водоём резервуар вода комфорт питомца полезный водный процедура лето жаркий погоду прожорливы необходимый высококачественный едак пища добавлять рыбий жир целое укреплять иммунитет улучшать внешний любимца вводить рацион диета допустимый наличие мясо птицы рыбы запретить кормить обладать железный здоровьем иметь уязвимый места существенный болезнь связать попадание грязь ушной проход минимизировать проблема можно правильно ухаживать ушами осматривать чистить регулярно проблема заключаться том ушной раковина питомец закрыты любой инфекция способный распространяться такой условиях вызывать воспаление дискомфорт курчавый  предать добряк настоящий друзья необходимый постоянный уход сторона хозяина иначе шерсть стать грязный причинять дискомфорт проявить забота четверолапый отплатить искренний любовью дать заскучать детям усидеть месте весьма жизнерадостны
#
# Порода: Левретка
# Цена: 35.00
# Рост: 35.00
# Вес: 4.00
# Опыт ухода: Да
# Релевантность: 0.8926597833633423
# Описание: левретка ить итальянский грейхаунд малый итальянский борзая  порода декоративный собака многочисленный семейство борзых эпоха средневековье богатый дама содержать собачка покой качество компаньона использовать травильный охота кролик куропаток день милый пёсик устойчивый занимать позиция верный ласковый домашний питомца итальянский левретка  самый миниатюрный среди борзых невероятно утончить обтекаемый силуэт тела граничить худобой никой образ портить фигура животного отлично развитой мускулистый тело прекрасный резвость преследовать добычу развивать больший скорость охота борзая способный самостоятельно принимать решения вести зверь твёрдый упорство целеустремленно левретка использовать охоты порода участвовать спортивный бега механический зайцем ключевой породный характеристики дефекты ведущий породный дисквалификации итальянский миниатюрный борзая  дружелюбное общительный невероятно игривый животное обожать центр внимания темперамент  типичный холерик свойственный моментальный возбудимость чрезмерный проявление эмоциональности основный цель жизнь  постоянный контакт человеком обладать развитой умом поэтому мера такт чуждый собачки любвеобильный нежна искренний любить хозяин член семьи предпочитать выражать чувство тактильный ласками легко подстраиваться образ жизни стремиться обнять поцеловать владельца обязательно постараться вылизать рука лицо яркий грациозность аристократичность животное  обманчива дело являться сильный целеустремлённый личность качество лидера поведение левретка абсолютно невозможно предугадать возможно провести тихо наслаждаться ничегонеделание тёплый лежанке устать скакать жилищу хитринка игнорировать просьба хозяин угомониться начинать хулиганить размахом несмотря активный нрав гиперэмоциональность порода дружить детьми удовольствие участвовать ребячий играх замечательный уживаться кошка собаками выстраивать прочный приятельский отношения вид мелкий живность борзая моментально срабатывать охотничий инстинкт незнакомый человек относиться недоверчиво стараться облаять поэтому выполнять обязанность охранника порода характерный чрезмерный разговорчивость собака обожать полаять поэтому квартирный содержание следовать отучать привычки иначе избежать конфликт соседями история малый итальянский борзая уходить свой корень древний египет среди египетский фараон богема считаться престижный покой подобный собак время грейхаунд завезти грецию разведение древний рим считаться популярный занятием пик невероятный слава левретка припадать эпоха возрождения обожать порода династия медичи мастистый мастер кисть гравёр завалить заказ вельможа венценосный особа портрет общество левреток конец 18 век порода стать терять популярность видеть снижение интерес собакам заводчик рискнуть заняться привнесение новизна экстерьер борзых зачастую эксперимент уменьшение рост низкорослый животное доходить крайностей 1873 английский клуб собаководство удаться приостановить своеволие селекционеров одновременно клуб начать работа стандартизация породы полностью проигнорировать появиться минилевреток первый десятилетие 20 век борзая попасть разряд непопулярный пород начаться вырождение начало 30й год левретка прилить кровь карликовый пинчер уиппета свой появление россия итальянский борзая обязать пётр i первый владелец порода российский империи екатерина великая быть поклонница левреток сделать популяризация стране начало революция 1917 численность борзая резко сократилась спустя 60 возрастать интерес порода среди советский собаководов выбор питомец следовать знать первый течка самка наблюдаться 812 месяцев продолжительность 1820 дней левретка относиться поздно физически психологически взрослеть породам полный взросление девочка достигать 115 лет мальчик 2 годам поэтому первый вязка следовать планировать двухлетний возраста ранний случка вести различный осложнениям удачный период вязка считаться 1115 сутки день пустовки неделя вязки вязки левретка являться типичный житель дом либо квартиры цепь вольер рассматриваются содержание  ...
#
# Порода: Эстонская гончая
# Цена: 20.00
# Рост: 45.00
# Вес: 17.50
# Опыт ухода: Да
# Релевантность: 0.8752188086509705
# Описание: эстонка элегантна неутомимый изящна крупный бигль русский гончей милый ласковый дома лес становиться свирепый настойчивый преследователем активная готовый приключение путешествие любимый хозяином доставлять хлопот воспитывать начинать детства эстонка предать владельцу любить детей обладать удивительный лаем звонким приятный слух бесстрашный вынослива поднять мелкий зверя кабан медведя злоба агрессия оставлять улице дом превращаться ласковый покладистый любимца содержание питомец гончий нежелательно зверушка рисковать объект ловли того легавый запах домочадец считать родным гнать дичь подобный запахом главный особенности миниатюрный охотница дружелюбная неугомонная привязать семье загородный  идеальный вариант квартира чувствует возможность выплеснуть энергию легавый чистоплотна легко приспосабливается дрессировать гончий легко преследование трудно равных стандартный обучение сложнее поэтому воспитание социализация важно начинать 3  4 месяцев пёс быстро запоминать команды добросовестно выполняет стараться угодить хозяину четвероногий красотка любить детей подбегать улице поиграть учесть обучении малышка приемлет крик грубость обижаться расстраивается баловать надо щенка питомец захотеть независимым воспринимать глава дом вожак стаи правильный подход ладить другой собаками мгновенно дать отпор случай опасности охотник готовый проявить щенячий возрасте охотно участвовать выставка полевой испытаниях особо талантливый завоёвывать награда 7  8 месяцев благодаря смелость настороженность чужим выполнять сторожевой функции собакаэстонка иметь большой распространения пользоваться мошенники продавать щенок порода вид красавиц нужный компаньон друг достаточно убедиться здоровье малыш наличие необходимый прививок случай возможно приобретение отдельный заводчик клубе планироваться охота покупать желательно племенной питомниках обязательно обращать внимание родословную соответствие стандартам четырехлапый простой капризна жить любой условиях важно учесть гиперактивна поэтому необходимый длительный прогулка 4  5 км дважды день бег поводок физический нагрузки легко адаптироваться любой температурам зимой следовать содержать дом утеплить будке сильный резкий запах ухудшать нюх уход стандартный процедуры калорийный сытное собака охотничий пород корм допускаться типов сухой обязательно премиум класса натуральный совмещать нельзя выбрать один взрослый особь есть дважды день щенок 4  5 раз пища рекомендоваться подогревать солить кормить стола охотница пьет должный свежий достаточный объеме давать запрещено болеет среднее жить 12  13 лет существовать склонность к прибалтиец  всеобщий любимец отважный охотник стать компаньон активный отдых игр подойти семья детьми неприхотливый ненавязчив правильный воспитание ласка  залог счастливый жизнь четырехлапый владельца
#
# Порода: Боксер
# Цена: 72.50
# Рост: 58.00
# Вес: 30.00
# Опыт ухода: Нет
# Релевантность: 0.8430256843566895
# Описание: боксёр  энергичный сильный собака вывести германии представитель порода считаться один самый выносливый мире активно использовать качество служебный собака сторожей отлично демонстрировать качество компаньон друг весь семьи боксёр обладать достаточно устрашать внешний видом несмотря считаться хороший семейный собака нянька детей представитель порода легко устанавливаться контакт людьми легко распознавать намерение человека несмотря это собака постоянно обучать иначе испортиться характер стать неуправляемой представитель порода отлично демонстрировать качество семейный собаки готовый оповестить опасности использовать качество сторожа предок порода охотничий собаки боксёр специфический характер собака готовый защитить хозяин цена жизни боксёр бесстрашный преданные легко поддаваться обучение поскольку обладать острый умом представитель дать порода отлично ладить детьми заводить качество семейный питомца боксёр позитивные игривые обожать бегать требовать значительный физический нагрузки удовольствие играть ребёнок школьный возраста боксёр оставлять малышами представитель порода склонный агрессии позволить навредить ребёнок обидит другой животное боксёр уживаться трудом собаками воинственно настроить другой собакам выгул боксёр держать поводке броситься погоня кошка мелкий животным немецкий боксёр хитрые сочетаться злобный защитник игривый щенок пёс удовольствие играть хозяином стоить забывать порода создать охоты одновременно боксёр требовательный уходе отлично уживаться квартире боксёр рекомендовать заводить начинающий собачникам иметь дело воспитание дрессировка собаки владелец замечательный питомец стоить знать боксёр любить одиночество требовать любовь внимание человека представитель порода плохо переносить холод сквозняк поскольку короткий шерсть важно ранний детство обучать щенка неправильный воспитание собака манипулировать хозяин попрошайничать учёт того порода склонный ожирение заболевание кишечника привести проблема негативный момент являться боксёр сильный слюнотечение сон храпят отказаться обваляться грязи версия появление породы точный зарождение порода неизвестны несомненный оставаться факт близкий предок боксёр являться вымереть быкодава  охотничий порода широко распространить xvii веке период быкодава незаменимый спутник охотник травля крупный дичи широкий распространение огнестрельный оружие быкодав переквалифицировать сторожевой собака xix век территория германия скрестить быкодава английский бульдога эксперимент проводить цель снизить агрессивность порода улучшить физический характеристики такой образ 1850 немецкий боксёр представить широкий публика выставка мюнхене создать клуб породы начало xx век определить стандарт прежде приобрести щенок рекомендоваться посетить выставки близкий познакомиться породой следующий дело пообщаться заводчиками смочь узнать кормить будущее питомца содержать необходимо родитель щенок поскольку питомец вырастет полный копией возможность поиграть щенками вероятно один установить контакт маленький щенок должный любопытный игривыми шерсть глаз ушко чистыми маленький щенок должный отчётливо просматриваться стандарт породы ухаживать боксёр несложно рацион боксёр сбалансированным кормить питомец премиальный сухой кормами состав включить витамин микроэлементы необходимый здоровье питомца хозяин домашний любимец выбирать натуральный питание рацион собака включают боксёр потомок охотничий собак поэтому каждый порция включать 80 мяса составление меню собака важно учитывать боксёр склонный ожирению хозяин выбрать домашний любимец натуральный питание необходимо добавлять специальный витаминный комплекс суспензии содержать кальций минеральный соль питательный вещества собака порода боксёр запрещаться давать боксёр кости поранить пищевод животного собака разрешаться говяжий бедренный кости животное раскусить смочь поточить зуб них боксёр отлично уживаться квартира частный доме представитель порода беречь холод сквозняка короткий шерстяной покров боксёр нужный физический нагрузка специфи ...
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
results_asym = asymmetric_search(query, cost, sheds, height, weight, care_experience, 5)

# Вывод результатов асимметричного поиска
for result in results_asym:
    print(f"Порода: {result['Name']}")
    print(f"Цена: {result['Original Cost']:.2f}")
    print(f"Рост: {result['Original Height']:.2f}")
    print(f"Вес: {result['Original Weight']:.2f}")
    print(f"Опыт ухода: {'Да' if result['Care Experience Needed'] == 1 else 'Нет'}")
    print(f"Релевантность: {result['Relevance Score']}")
    print(f"Описание: {result['Description']}\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Порода: Малая бельгийская собака
# Цена: 45.00
# Рост: 19.00
# Вес: 4.00
# Опыт ухода: Нет
# Релевантность: 0.8291794061660767
# Описание: малый бельгийский собака ить гриффон конюшенный гриффон  секция три декоративный порода собак входят давний время крохотный пёсик использоваться охрана дома уничтожение грызун питомец человек разный сословие  аристократ простолюдинов день являться домашний любимцами участвовать выставочный шоу разновидность гриффон произойти маленький жесткошёрстный собачка smousje существует когдато обитать окрестность бельгийский столицы отличаться цвет тип волосяной покрова брюссельский бельгийский гриффон характерный ус бородка морде отсутствовать брабанского гриффон  невероятно энергичный харизматический животное который любой сутки готовый проказничать играть натура наглый дерзким совершенно переносить одиночество начинать грустить отсутствие хозяина обожать любить свой маленький сердцем домочадец питомец чрезвычайно любвеобилен хозяин считаться самый главный свете ребёнок школьный возраст  разлить вода охотно участвовать детский шалостях собачка нравиться шумный активный игры малыш отношение складываются поскольку маленький человечек воспринимать соперника другой домашний животное уживается чужой питомец относиться насторожить облаять несмотря миниатюрный габариты охотно взваливать обязанность охранник жилища звонкий голос извещать приход гостей дрессировка воспитание  усердный ученик условие последовательно выстроить учебный процесса поэтому сторона хозяин должный твёрдость требовательность качество поощрение использовать лакомство похвалу средний цена щенок гриффон 4050 рублей гриффон  абсолютно диванный собачка нуждаться постоянный внимании несмотря крохотный размеры питомец требоваться прогулка свежий воздух активный нагрузки соизмеримый габаритами уход питомец заключаться такой процедурах малый бельгийка нуждаться сбалансированный питании питомец подойти промышленный корм премиум класс мелкий порода домашний пища кормление натуральный продукт меню должный присутствовать порода обладать сравнительно крепкий здоровьем предрасположенность отдельный патологиям обусловить физиологический особенность организма средний длительность жизнь 1315 лет малый бельгийский собака подойти людям хотеть завести диванный питомец весёлый игривый характером приобретать милый собачку стоить забывать игрушка живой существо которое крупный породы нуждаться внимании воспитание прогулках
#
# Порода: Шотландская овчарка (колли)
# Цена: 55.00
# Рост: 56.00
# Вес: 25.00
# Опыт ухода: Нет
# Релевантность: 0.8205438852310181
# Описание: милый создание зваться собака пастуха шотландский английский колли лесси длинный вытянутый мордашка обворожительный кокетливый взгляд красивый окрас шелковистый шубка миролюбивый характер сообразительность красотка  достоинство привлекать ценитель аристократичный четвероногих обаяшек характерный высокий интеллектуальный способности любознательность спортивность игривость энергичность существовать разный вид шотландцев отличие первый второй вид длина шерсти первый наблюдаться пышный покров шерсти второй  шерсть короткая активный энергичный характер высокий говорливость бородач бердь  редкость среди шотландцев являться прямой предок английский пастухов грань исчезновения бордер английский переводиться граница пойти название бордерколли овчаркакрасотка брать исток пастуший шотландский английский псов самый дружелюбный собаки спокойно оставлять следить домашний птицей шелтить  маленький представитель пушистый хвостиков рост составлять 41 см длинномордый пушинка представлять аристократичный красивый псов высокомерно смотреть окружающих хитринкой дружелюбие явный приветливостью данный момент обаяшка заниматься пастуший деятельностью являться приблизить друг людей длинношерстика отличаться прекрасный вкусом являться обладатель роскошный шевелюра воротник  достаться стремление заводчик достигнуть идеала стандарт декларировать 3 базовый масти дополняться образ белый манишкой воротничком снежнобелый кончик хвост гольфиками лапках шотландский очаровашка  создание высокий интеллектом который хотеть часть хозяев дружеский отношение всеми сородич кошками милый пушистик характер темперамент крайностей главный особенность животное заключаться поэтому легко уживаться доме четвероногий устроить погром любить поиграть побегать наличие угроза очаровашка стать показывать негативный отношение чужак стать скалиться рычать изза редко встретить роль телохранителя доставаться розыск караул смело оставлять ребёнок длинномордый телохранителем опасаться безопасность пушинка принимать роль няня детей вырастить сиделка ребёнок самостоятельно псы иметь контакт ребёнок взрослый возраста дружелюбный чадам всем встречаться обаяшками известно необыкновенный говорливость питомцев иметься вид реакция звук посторонний шумы обычный разговор хозяином задавать маленький хвостику удивляйтесь услышать ответ чтото лающий завывающее другой существо лесси относиться дружелюбно защищать опасность некрупный скот домашний птицу плохой поведение длинномордый очаровашка проявиться компанию четвероногий гоняться кошка ктото другим развлечение очаровашка скорее всего поддержит инстинкт стая играть один важный роль жизнь пастуха стоить характеристика относиться к шотландский овчаркам индивидуальный непохожий друга описание давать общий черта особенность шотландский четвероногих различие заметный сравнение мосек жить разный условие содержания американский пёсик отличаться европейский сильный темпераментом проводить различие коротко длинношерстными сказать первый управляемый энергичные вторые выведение шотландский овчарка начаться xix века воспринимать охранник скота королева виктория пёсик имя нобл появиться очаровашкипастухи привести известность распространение поголовье фаворитов 1860 среди пастушок произойти разделение который повлечь выделение семейство крупный особь рыжеть густой гривой постепенно начать формироваться подвид шустриков то выглядеть уроженец шотландия настоящий времени стать результат многий скрещивание заводчиков длинный форма морда приобрести русский борзой рыжекрасный окраска волосяной покров подарил ирландский сеттер выработать определённый генотип особь оказаться сложнее мочь долгий годы наконец 1885 выставка начать встречаться красавцы похожий современный шотландцев один такой олд коки звезда ринг времени век зародиться коротко длинношёрстный вид длинномордый очаровашек несмотря то пёсик короткий длинный шерсть скрещивать вплоть конец xx века относиться разный породный подтипам короткий шерсть странно являться редкость среди длинномордый собратье ...
#
# Порода: Малая львиная собака
# Цена: 200.00
# Рост: 29.00
# Вес: 6.00
# Опыт ухода: Нет
# Релевантность: 0.8198914527893066
# Описание: малый львиный собака ить левхен лоучен петит шьен лион бишон лион львиный собачка  старинный порода декоративный собак род франции замечательный компаньон любимец семьи абсолютно капризный уход обучении петит шьен лион  ласковый послушная подвижный весёлый собачкаинтеллектуал приподнять настроении любой сутки готовый общению счастливый окружение член семьи сильно обижаться расстраиваться отсутствие внимание персоне совершенно переносить одиночество поэтому следовать оставлять надолго маленький львенка длительный разлука хозяин негативно отражаться психический физический здоровье питомца начинать скучать грустить быстро гаснут глазах безгранично обожать хозяина стремиться порадовать взамен ожидать похвала ласку отказаться лакомства чрезвычайно миролюбивый спокойный пёсик  настоящий дипломат уметь уступать практически провоцировать открытый конфликт ребёнок относиться ласково нежно моментально находить общий язык лоучить быстро становиться самый хороший друзьями отлично уживаться другой домашний питомцами кошка хомячками теми который расти щенячий возраста несмотря маленький габарит статус декоративный породы отважный смелый создание который готовый встать защита член семьи незнакомый человек относиться осторожно дружелюбно бишон лион выглядеть игрушечным нуждаться полноценный социализации воспитание дрессировке начинать преподносить аз наука любимец следовать двухмесячный возраста легко обучаться неопытный владельцев средний цена щенок лехен 180220 рублей маленький львиный собака идеально подойти дом квартиры нуждаться ежедневный прогулках гулять собака час день уход бишонлеон несложен кормление питомец подходить промышленный корм премиум класс натуральный продукты кормление домашний еда основа меню являться мясо нежирный сорт субпродукты дополнительно дают польза принести витаминноминеральный добавки малый львиный собачка обладать отменно крепкий иммунитетом уязвимый некоторый наследственный заболеваниями средний длительность жизнь 1215 лет приятный характер компактный размер лоучена делать привлекательный питомец широкий круг людей мечтать компактный четвероногий друге порода подойти человек единственный случае трудоголик редко дома
#
# Порода: Аппенцеллер зенненхунд
# Цена: 37.50
# Рост: 52.00
# Вес: 25.00
# Опыт ухода: Нет
# Релевантность: 0.8002344965934753
# Описание: собака порода аппенцеллер зенненхунд считаться один самый дорогих желанный питомцев ценить дружелюбный отзывчивый характер превосходный физический развитость высокий уровень взаимопонимание человеком симпатичный требовать сложный ухода уравновешенный труд поддаваться дрессировке являться превосходный сторожами использовать охрана скота окраска присутствовать триколор отличительный особенность являться закрутить хвостик внешне тело собака выглядеть аккуратно стройно характер компанейский искренне предать свой хозяину среди главный черта характер следовать отметить приобрести щенок россия непросто порода распространена сложно поэтому высокий стоимость четвероногих следить состояние шерсть желательно ежедневно расчёсывать стоит минимум 1 неделю линьки явно проявляться осень весной следовать регулярнее выгуливать такой питомец прийтись 2 раз день утром вечером прогулка должный занимать часа животное активное хороший вариант проживание считать загородный частный собственный сад широкий двором такой условие пёс больший успех суметь реализовать сторожевой навыки кормление подойти премиальный корм средний крупный пород рацион должный главенствовать занимать натуральный пища представить необходимо предусмотреть постоянный доступ питьевой воде кой случай предлагать мясной трубчатый кости иммунитет отличаться стойкостью здоровье отменный протяжение больший часть жизни недуг начинать возникать гдето 810 лет зрелый возраст общий продолжительность жизнь составлять 15 лет среди основный присущий заболевание выделять следующее мечтать сильной активный жизнерадостный собаке стать надёжный друг помощником смело заводить красавец аппенцеллера относительно высокий стоимость быстро компенсироваться целый гамма яркий эмоция тёплый воспоминаний подарить отзывчивый пёс
#
# Порода: Манчестер-терьер
# Цена: 50.00
# Рост: 39.00
# Вес: 7.50
# Опыт ухода: Да
# Релевантность: 0.7968818545341492
# Описание: манчестертерьер ить манчестерский терьер  английский старинный порода манчестер закрепиться слава непревзойдённый крысолова выступать достойный конкурент кошек собака участвовать спортивный соревнование охоте являться замечательный семейный питомцами манчестертерьер  результат скрещивание уипета уэстхайлендуайттерьер исчезнуть английский черноподпалый терьера существовать разновидность манчестер  тот стандарт ранее считаться отдельный породами сегодняшний объединить одну различие заключаться форма уха манчестерский терьер  жизнерадостный животное который гармонично сочетаться интеллигентный утонченность сила достоинство благоразумие преданность свой характер питомец энергичен азартен поэтому длительный посиделки него хозяин относиться тепло стараться поддерживать тесный контакт оставаться кошка независимым длительный одиночество переносит начинать тосковать владельцем домочадец выстраивать дружеский отношения ребёнок вести хорошо назойливый приставание потерпит укусить присутствие домашний животное примиряется настоящий дружба нет поскольку выраженный охотничий инстинкт подталкивать собачка погонять кошка другой мелкий живность незнакомец воспринимать агрессии излишний общение стараться избегать неплохой сторож бдительно охранять хозяйский территорию необходимость готовый защитить близкий людей увлекаться своеобразный хобби  стойкий упорство рыть ямка цветник овощной грядка делать подкоп забором нуждаться ранний социализация воспитании отлично поддаваться дрессировке стремиться угодить хозяину условии владелец глаз  лидер средний цена щенок манчестертерьер 4060 рублей манчестертерьер подходить содержание дом квартире жаркий следить питомец перегреться солнцепеке зимой беречь переохлаждения уход манчестер неприхотлив порода подходить промышленный корм премиум класс суперпремиум класс натуральный еда кормление домашний пища меню включают манчестертерьер крепкий здоровье порода страдать некоторый наследственный болезнями средний длительность жизнь 1416 манчестерский терьер  элегантно представительный порода требоваться опытный владелец активный образ жизни порода рекомендоваться домосед человек чрезмерно рабочий занятостью питомец нуждаться внимании ежедневный прогулка физический занятиях

# %%
dog_data[dog_data['Name'] == 'Фараонова собака']
# Out:
#                  Name                                       Link  \
# 297  Фараонова собака  https://doge.ru/poroda/faraonovaya-sobaka
#
#      Average Cost  Average Lifespan  Sheds Little  Sheds  Sheds A Lot  \
# 297      0.112745              16.0           1.0    0.0          0.0
#
#      Average Litter Size  Average Height  Average Weight  Care Experience  \
# 297                  6.5       -0.113079       -0.103905              1.0
#
#                                            Description  \
# 297  фараоновый собака ить фарао хаунд род мальты с...
#
#                                                  Image  \
# 297  https://images.prismic.io/doge/74578921-5ba8-4...
#
#                                              embedding  \
# 297  [0.016547062, 0.549206, -0.14716125, -0.001270...
#
#                                     combined_embedding
# 297  [0.016547061502933502, 0.549206018447876, -0.1...

# %%
sbert_model.save('sbert_model')
cross_encoder.save('cross_encoder')

# %%
np.save('dog_embeddings.npy', combined_embeddings)

# %%
dog_data.to_csv('cleaned_new.csv', index=False)

# %%
faiss.write_index(index, 'faiss_index.bin')

# %%
import joblib
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']
